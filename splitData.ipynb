# %% [markdown]
# # On divise le data set entre train et test

# %% [markdown]
# On charge les libraries voulues :

# %%
import pyensae
import pyquickhelper
import pandas, sqlite3, os
path = "data/"
pathTrain = path+"training_set/"
pathWD = "\\\\paradis\\eleves\\BDonnot\\Bureau\\DonneesMassives\\"
#pathWD = "\\Documents\DonneesMassives\\"
#os.chdir(pathWD)

# %% [markdown]
# On se connecte au serveur

# %%
params={"blob_storage":"hdblobstorage", "password1":"", "hadoop_server":"clusterensaeazure1", "password2":"", "username":"DonnotLaugel"}
with open("password","r") as fPassWord :
    for line in fPassWord :
        li = line.split(":")
        if li[0] == params["blob_storage"] :
            params["password1"] = li[1].replace('\n','').replace('\r','')
        elif li[0] == params["hadoop_server"] :
            params["password2"] = li[1].replace('\n','').replace('\r','')
pyquickhelper.open_html_form(params=params,title="server + hadoop + credentials", key_save="blobhp")
# Out:
# <div style="background-color:gainsboro; padding:2px; border:0px;"><b>server + hadoop + credentials</b>
# <br />blob_storage <input type="text" id="blobhpblob_storage" value="hdblobstorage" size="80" />
# <br />hadoop_server <input type="text" id="blobhphadoop_server" value="clusterensaeazure1" size="80" />
# <br />password1 <input type="password" id="blobhppassword1" value="jQIPVO/T54w8X49UPIbzAVvaNO3wmuUwI4/o9AJnCaPTHoCQnsaGBUkT4eIyi0BRQavgc/TAQMQwy8eu19CSBQ==" size="80" />
# <br />password2 <input type="password" id="blobhppassword2" value="2azureENSAE;" size="80" />
# <br />username <input type="text" id="blobhpusername" value="DonnotLaugel" size="80" />
# <br /><button onclick="set_valueblobhp()">Ok</button></div>
# <script type="text/Javascript">
# function blobhpcallback(msg) {
#    var ret = msg.content.data['text/plain'];
#    $('#outblobhp').text(ret);
# }
# function set_valueblobhp(){
#    command='blobhp = {' ;
#    var blobhpblob_storagevar_value = document.getElementById('blobhpblob_storage').value;
#    command += '"blob_storage":"' + blobhpblob_storagevar_value + '",';
#    var blobhphadoop_servervar_value = document.getElementById('blobhphadoop_server').value;
#    command += '"hadoop_server":"' + blobhphadoop_servervar_value + '",';
#    var blobhppassword1var_value = document.getElementById('blobhppassword1').value;
#    command += '"password1":"' + blobhppassword1var_value + '",';
#    var blobhppassword2var_value = document.getElementById('blobhppassword2').value;
#    command += '"password2":"' + blobhppassword2var_value + '",';
#    var blobhpusernamevar_value = document.getElementById('blobhpusername').value;
#    command += '"username":"' + blobhpusernamevar_value + '",';
#    command += '}';
#    var kernel = IPython.notebook.kernel;
#    kernel.execute(command);
# }
# </script>

# %%
blobstorage = blobhp["blob_storage"]
blobpassword = blobhp["password1"]
hadoop_server = blobhp["hadoop_server"]
hadoop_password = blobhp["password2"]
username = blobhp["username"]
client, bs =  %hd_open
client, bs
# Out:
# (<pyensae.remote.azure_connection.AzureClient at 0x7f008479a978>,
#  <azure.storage.blobservice.BlobService at 0x7f008479a9e8>,
#  'hdblobstorage',
#  'DonnotLaugel')

# %% [markdown]
# On vérifie que les précédents fichiers sont bien là

# %%
l = %blob_containers
l
# %blob_ls /$PSEUDO/DonnotLaugel
# Out:
#                                            name  \
# 0  DonnotLaugel/DonnotLaugel/allNetflixData.csv
#
#                    last_modified              content_type  content_length  \
# 0  Mon, 02 Feb 2015 16:59:38 GMT  application/octet-stream      2610540665
#
#    blob_type
# 0  BlockBlob

# %% [markdown]
# ##### On créé le job pig pour convertir les dates (inutile) :

# %%
# %%PIG convert_date.pig
#
# allData = LOAD '$CONTAINER/$PSEUDO/DonnotLaugel/allNetflixData.csv' USING PigStorage(',') AS (movie:int,user:int,rating:int,date:chararray );
#
# values = FOREACH allData GENERATE (datetime) ToDate(date,'yyyy-MM-dd') AS date2 ;
#
# STORE values INTO '$CONTAINER/$PSEUDO/DonnotLaugel/allNetflixDataClean.csv' USING PigStorage(',') ;

# %% [markdown]
# On Lance le job

# %%
if client.exists(bs,client.account_name,"$PSEUDO/DonnotLaugel/allNetflixDataClean.csv") :
        r = client.delete_folder(bs,client.account_name,"$PSEUDO/DonnotLaugel/allNetflixDataClean.csv")
client.pig_submit(bs, client.account_name, 'convert_date.pig')
#%hd_pig_submit convertDate.pig -stop_on_failure
# Out:
# {'id': 'job_1422019453959_0782'}

# %% [markdown]
# On vérifie l'état d'avancement du job :

# %%
#don't forget to change the job_id ...
st = %hd_job_status job_1422019453959_0782
st["id"],st["percentComplete"],st["status"]["jobComplete"]
# Out:
# ('job_1422019453959_0782', '100% complete', True)

# %% [markdown]
# On vérifie que le job s'est bien déroulé

# %%
# %tail_stderr job_1422019453959_0782 50
# Out:
# <pre>
# 2015-02-03 13:51:12,188 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Processing aliases allData,values
# 2015-02-03 13:51:12,188 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - detailed locations: M: allData[2,10],values[-1,-1] C:  R:
# 2015-02-03 13:51:12,313 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 0% complete
# 2015-02-03 13:52:22,843 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 4% complete
# 2015-02-03 13:53:02,390 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 8% complete
# 2015-02-03 13:53:41,859 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 12% complete
# 2015-02-03 13:54:20,847 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 16% complete
# 2015-02-03 13:55:16,673 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 20% complete
# 2015-02-03 13:55:46,908 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 24% complete
# 2015-02-03 13:56:11,360 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 28% complete
# 2015-02-03 13:56:37,268 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 32% complete
# 2015-02-03 13:57:02,659 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 36% complete
# 2015-02-03 13:57:28,082 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 40% complete
# 2015-02-03 13:57:53,973 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 45% complete
# 2015-02-03 13:58:22,741 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 49% complete
# 2015-02-03 13:58:44,189 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2015-02-03 13:58:44,330 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 100% complete
# 2015-02-03 13:58:44,330 [main] INFO  org.apache.pig.tools.pigstats.SimplePigStats - Script Statistics:
#
# HadoopVersion	PigVersion	UserId	StartedAt	FinishedAt	Features
# 2.4.0.2.1.6.0-2103	0.12.1.2.1.6.0-2103	hdp	2015-02-03 13:51:00	2015-02-03 13:58:44	UNKNOWN
#
# Success!
#
# Job Stats (time in seconds):
# JobId	Maps	Reduces	MaxMapTime	MinMapTIme	AvgMapTime	MedianMapTime	MaxReduceTime	MinReduceTime	AvgReduceTime	MedianReducetime	Alias	Feature	Outputs
# job_1422019453959_0784	5	0	209	178	198	202	n/a	n/a	n/a	n/a	allData,values	MAP_ONLY	wasb://hdblobstorage@hdblobstorage.blob.core.windows.net//DonnotLaugel/DonnotLaugel/allNetflixDataClean.csv,
#
# Input(s):
# Successfully read 100480507 records from: "wasb://hdblobstorage@hdblobstorage.blob.core.windows.net//DonnotLaugel/DonnotLaugel/allNetflixData.csv"
#
# Output(s):
# Successfully stored 100480507 records in: "wasb://hdblobstorage@hdblobstorage.blob.core.windows.net//DonnotLaugel/DonnotLaugel/allNetflixDataClean.csv"
#
# Counters:
# Total records written : 100480507
# Total bytes written : 0
# Spillable Memory Manager spill count : 0
# Total bags proactively spilled: 0
# Total records proactively spilled: 0
#
# Job DAG:
# job_1422019453959_0784
#
#
# 2015-02-03 13:58:44,330 [main] WARN  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - No FileSystem for scheme: wasb. Not creating success file
# 2015-02-03 13:58:44,330 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at headnodehost/100.74.20.101:9010
# 2015-02-03 13:58:44,440 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2015-02-03 13:58:45,847 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Success!
#
# </pre><br />

# %% [markdown]
# On vérifie le contenu du blob storage :

# %%
# %blob_ls /$PSEUDO/DonnotLaugel
# Out:
#                                                 name  \
# 0       DonnotLaugel/DonnotLaugel/allNetflixData.csv
# 1  DonnotLaugel/DonnotLaugel/allNetflixDataClean.csv
# 2  DonnotLaugel/DonnotLaugel/allNetflixDataClean....
# 3  DonnotLaugel/DonnotLaugel/allNetflixDataClean....
# 4  DonnotLaugel/DonnotLaugel/allNetflixDataClean....
# 5  DonnotLaugel/DonnotLaugel/allNetflixDataClean....
# 6  DonnotLaugel/DonnotLaugel/allNetflixDataClean....
# 7  DonnotLaugel/DonnotLaugel/allNetflixDataClean....
#
#                    last_modified              content_type  content_length  \
# 0  Mon, 02 Feb 2015 16:59:38 GMT  application/octet-stream      2610540665
# 1  Tue, 03 Feb 2015 13:58:40 GMT                                         0
# 2  Tue, 03 Feb 2015 13:58:40 GMT  application/octet-stream               0
# 3  Tue, 03 Feb 2015 13:58:38 GMT  application/octet-stream       516205875
# 4  Tue, 03 Feb 2015 13:58:39 GMT  application/octet-stream       517147950
# 5  Tue, 03 Feb 2015 13:58:39 GMT  application/octet-stream       517401875
# 6  Tue, 03 Feb 2015 13:58:39 GMT  application/octet-stream       516689025
# 7  Tue, 03 Feb 2015 13:58:39 GMT  application/octet-stream       444567950
#
#    blob_type
# 0  BlockBlob
# 1  BlockBlob
# 2  BlockBlob
# 3  BlockBlob
# 4  BlockBlob
# 5  BlockBlob
# 6  BlockBlob
# 7  BlockBlob

# %% [markdown]
# ##### On créé un histogramme pour pouvoir séparer convenablement la base en train/test :

# %%
# %%PIG create_histogram_by_date.pig
#
# values = LOAD '$CONTAINER/$PSEUDO/DonnotLaugel/allNetflixData.csv' USING PigStorage(',') AS (movie:int,user:int,rating:int,date:chararray);
#
# values_hist = GROUP values BY date;
#
# hist = FOREACH values_hist GENERATE group,COUNT(values) AS nb ;
#
# STORE hist INTO '$CONTAINER/$PSEUDO/DonnotLaugel/HistoNetflixData.csv' USING PigStorage(',');

# %%
job = client.pig_submit(bs, client.account_name, "create_histogram_by_date.pig")
job
# Out:
# {'id': 'job_1422019453959_0910'}

# %%
st = %hd_job_status job_1422019453959_0910
st["id"],st["percentComplete"],st["status"]["jobComplete"]
# Out:
# ('job_1422019453959_0910', '100% complete', True)

# %%
# %tail_stderr job_1422019453959_0910 50
# Out:
# <pre>
# 2015-02-03 16:27:46,941 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - HadoopJobId: job_1422019453959_0911
# 2015-02-03 16:27:46,941 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Processing aliases hist,values,values_hist
# 2015-02-03 16:27:46,941 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - detailed locations: M: values[2,9],values[-1,-1],hist[6,7],values_hist[4,14] C: hist[6,7],values_hist[4,14] R: hist[6,7]
# 2015-02-03 16:27:47,050 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 0% complete
# 2015-02-03 16:29:01,395 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 4% complete
# 2015-02-03 16:29:30,254 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 8% complete
# 2015-02-03 16:29:58,881 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 12% complete
# 2015-02-03 16:30:40,664 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 16% complete
# 2015-02-03 16:31:10,459 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 20% complete
# 2015-02-03 16:31:43,897 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 24% complete
# 2015-02-03 16:32:20,647 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 28% complete
# 2015-02-03 16:32:48,886 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 35% complete
# 2015-02-03 16:33:06,835 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 43% complete
# 2015-02-03 16:33:19,581 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 53% complete
# 2015-02-03 16:33:24,976 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 60% complete
# 2015-02-03 16:33:26,069 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 83% complete
# 2015-02-03 16:33:34,655 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 100% complete
# 2015-02-03 16:33:34,671 [main] INFO  org.apache.pig.tools.pigstats.SimplePigStats - Script Statistics:
#
# HadoopVersion	PigVersion	UserId	StartedAt	FinishedAt	Features
# 2.4.0.2.1.6.0-2103	0.12.1.2.1.6.0-2103	hdp	2015-02-03 16:27:36	2015-02-03 16:33:34	GROUP_BY
#
# Success!
#
# Job Stats (time in seconds):
# JobId	Maps	Reduces	MaxMapTime	MinMapTIme	AvgMapTime	MedianMapTime	MaxReduceTime	MinReduceTime	AvgReduceTime	MedianReducetime	Alias	Feature	Outputs
# job_1422019453959_0911	5	1	303	255	290	297	19	19	19	19	hist,values,values_hist	GROUP_BY,COMBINER	wasb://hdblobstorage@hdblobstorage.blob.core.windows.net//DonnotLaugel/DonnotLaugel/HistoNetflixData.csv,
#
# Input(s):
# Successfully read 100480507 records from: "wasb://hdblobstorage@hdblobstorage.blob.core.windows.net//DonnotLaugel/DonnotLaugel/allNetflixData.csv"
#
# Output(s):
# Successfully stored 2182 records in: "wasb://hdblobstorage@hdblobstorage.blob.core.windows.net//DonnotLaugel/DonnotLaugel/HistoNetflixData.csv"
#
# Counters:
# Total records written : 2182
# Total bytes written : 0
# Spillable Memory Manager spill count : 0
# Total bags proactively spilled: 0
# Total records proactively spilled: 0
#
# Job DAG:
# job_1422019453959_0911
#
#
# 2015-02-03 16:33:34,671 [main] WARN  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - No FileSystem for scheme: wasb. Not creating success file
# 2015-02-03 16:33:34,671 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at headnodehost/100.74.20.101:9010
# 2015-02-03 16:33:34,764 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2015-02-03 16:33:36,733 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Success!
#
# </pre><br />

# %%
nameDL = "histo_by_day.txt"
if(os.path.exists("data/"+nameDL) ): os.remove("data/"+nameDL)
# %blob_downmerge /$PSEUDO/DonnotLaugel/HistoNetflixData.csv data/histo_by_day.txt
# Out:
# 'data/histo_by_day.txt'

# %%
DF = pandas.read_csv("data/"+nameDL,sep=",",names = ["date","count"])
a = DF["count"].cumsum()
#print(a[a > 666666].idxmin())

DF.ix[ a > 66666666,:],DF.shape
#dateMin: 2005-05-31 (see later)
# Out:
# (            date   count
#  1952  2005-05-16  208264
#  1953  2005-05-17  202079
#  1954  2005-05-18  162988
#  1955  2005-05-19  145705
#  1956  2005-05-20  132969
#  1957  2005-05-21   95288
#  1958  2005-05-22  118400
#  1959  2005-05-23  197363
#  1960  2005-05-24  189923
#  1961  2005-05-25  163470
#  1962  2005-05-26  143689
#  1963  2005-05-27  128412
#  1964  2005-05-28   92303
#  1965  2005-05-29   95123
#  1966  2005-05-30  120926
#  1967  2005-05-31  234062
#  1968  2005-06-01  238967
#  1969  2005-06-02  209225
#  1970  2005-06-03  184812
#  1971  2005-06-04  118950
#  1972  2005-06-05  134021
#  1973  2005-06-06  222474
#  1974  2005-06-07  220087
#  1975  2005-06-08  189604
#  1976  2005-06-09  170494
#  1977  2005-06-10  168522
#  1978  2005-06-11  125045
#  1979  2005-06-12  135907
#  1980  2005-06-13  218701
#  1981  2005-06-14  217113
#  ...          ...     ...
#  2152  2005-12-02   90091
#  2153  2005-12-03   70088
#  2154  2005-12-04   75942
#  2155  2005-12-05  113295
#  2156  2005-12-06  114358
#  2157  2005-12-07   95527
#  2158  2005-12-08   82646
#  2159  2005-12-09   78426
#  2160  2005-12-10   61260
#  2161  2005-12-11   66201
#  2162  2005-12-12   99387
#  2163  2005-12-13   88083
#  2164  2005-12-14   87649
#  2165  2005-12-15   70850
#  2166  2005-12-16   68734
#  2167  2005-12-17   57593
#  2168  2005-12-18   66640
#  2169  2005-12-19   96913
#  2170  2005-12-20   87338
#  2171  2005-12-21   78947
#  2172  2005-12-22   69366
#  2173  2005-12-23   59554
#  2174  2005-12-24   31622
#  2175  2005-12-25   30033
#  2176  2005-12-26   60109
#  2177  2005-12-27   87804
#  2178  2005-12-28   98671
#  2179  2005-12-29   97320
#  2180  2005-12-30   77599
#  2181  2005-12-31   45670
#
#  [230 rows x 2 columns], (2182, 2))

# %% [markdown]
# ##### On sépare la base entre train et test :

# %%
# %%PIG create_train_test.pig
#
# values = LOAD '$CONTAINER/$PSEUDO/DonnotLaugel/allNetflixData.csv' USING PigStorage(',') AS (movie:int,user:int,rating:int,date:chararray);
#
# values_Train = FILTER values BY (datetime) ToDate(date,'yyyy-MM-dd') <= (datetime) ToDate('20090630','yyyyMMdd');
#
# STORE values_Train INTO '$CONTAINER/$PSEUDO/DonnotLaugel/NetflixData_Train-2009-06-30.csv' USING PigStorage(',') ;
#
# values_Test = FILTER values BY (datetime) ToDate(date,'yyyy-MM-dd') > (datetime) ToDate('20090630','yyyyMMdd');
#
# STORE values_Test INTO '$CONTAINER/$PSEUDO/DonnotLaugel/NetflixData_Test-2009-06-30.csv' USING PigStorage(',') ;

# %%
# %%PIG create_train_test.pig
#
# values = LOAD '$CONTAINER/$PSEUDO/DonnotLaugel/allNetflixData.csv' USING PigStorage(',') AS (movie:int,user:int,rating:int,date:chararray);
#
# values_Train = FILTER values BY (datetime) ToDate(date,'yyyy-MM-dd') <= (datetime) ToDate((chararray) $dateMin,'yyyyMMdd');
#
# STORE values_Train INTO '$CONTAINER/$PSEUDO/DonnotLaugel/NetflixData_Train-$dateMin.csv' USING PigStorage(',') ;
#
# values_Test = FILTER values BY (datetime) ToDate(date,'yyyy-MM-dd') > (datetime) ToDate((chararray) $dateMin,'yyyyMMdd');
#
# STORE values_Test INTO '$CONTAINER/$PSEUDO/DonnotLaugel/NetflixData_Test-$dateMin.csv' USING PigStorage(',') ;

# %% [markdown]
# On envoie le job :

# %%
dateMin = "20050531" #review posted at this date are included in the training set.
if client.exists(bs,client.account_name,"$PSEUDO/DonnotLaugel/NetflixData_Train-%s.csv" % dateMin) :
        r = client.delete_folder(bs,client.account_name,"$PSEUDO/DonnotLaugel/NetflixData_Train-%s.csv" %dateMin)
if client.exists(bs,client.account_name,"$PSEUDO/DonnotLaugel/NetflixData_Test-%s.csv" % dateMin) :
        r = client.delete_folder(bs,client.account_name,"$PSEUDO/DonnotLaugel/NetflixData_Test-%s.csv" %dateMin)
job = client.pig_submit(bs, client.account_name, "create_train_test.pig",params = dict(dateMin=dateMin) )
job
#client.pig_submit(bs, client.account_name, "createTrainTest.pig")
# Out:
# {'id': 'job_1422019453959_0953'}

# %%
#client.job_kill("job_1422019453959_0842")
#client.job_queue(bs)

# %% [markdown]
# On vérifie que le job s'exécute normalement :

# %%
#don't forget to change the job_id ...
st = %hd_job_status job_1422019453959_0953
st["id"],st["percentComplete"],st["status"]["jobComplete"]
# Out:
# ('job_1422019453959_0953', '100% complete', True)

# %% [markdown]
# On vérifie qu'il n'y a pas eu d'erreur :

# %%
# %tail_stderr job_1422019453959_0953 50
# Out:
# <pre>
# 2015-02-03 17:42:25,443 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 8% complete
# 2015-02-03 17:42:58,740 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 12% complete
# 2015-02-03 17:43:31,692 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 16% complete
# 2015-02-03 17:44:05,132 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 20% complete
# 2015-02-03 17:44:38,489 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 24% complete
# 2015-02-03 17:45:11,459 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 28% complete
# 2015-02-03 17:45:44,926 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 32% complete
# 2015-02-03 17:46:17,974 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 36% complete
# 2015-02-03 17:46:53,505 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 40% complete
# 2015-02-03 17:47:29,883 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 44% complete
# 2015-02-03 17:48:15,775 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 48% complete
# 2015-02-03 17:48:52,205 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2015-02-03 17:48:52,268 [main] WARN  org.apache.pig.tools.pigstats.JobStats - unable to find an output size reader
# 2015-02-03 17:48:52,283 [main] WARN  org.apache.pig.tools.pigstats.JobStats - unable to find an output size reader
# 2015-02-03 17:48:52,315 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 100% complete
# 2015-02-03 17:48:52,315 [main] INFO  org.apache.pig.tools.pigstats.SimplePigStats - Script Statistics:
#
# HadoopVersion	PigVersion	UserId	StartedAt	FinishedAt	Features
# 2.4.0.2.1.6.0-2103	0.12.1.2.1.6.0-2103	hdp	2015-02-03 17:40:36	2015-02-03 17:48:52	FILTER
#
# Success!
#
# Job Stats (time in seconds):
# JobId	Maps	Reduces	MaxMapTime	MinMapTIme	AvgMapTime	MedianMapTime	MaxReduceTime	MinReduceTime	AvgReduceTime	MedianReducetime	Alias	Feature	Outputs
# job_1422019453959_0954	5	0	463	367	429	444	n/a	n/a	n/a	n/a	values,values_Test,values_Train	MULTI_QUERY,MAP_ONLY	wasb://hdblobstorage@hdblobstorage.blob.core.windows.net//DonnotLaugel/DonnotLaugel/NetflixData_Train-20050531.csv,wasb://hdblobstorage@hdblobstorage.blob.core.windows.net//DonnotLaugel/DonnotLaugel/NetflixData_Test-20050531.csv,
#
# Input(s):
# Successfully read 100480507 records from: "wasb://hdblobstorage@hdblobstorage.blob.core.windows.net//DonnotLaugel/DonnotLaugel/allNetflixData.csv"
#
# Output(s):
# Successfully stored 68895920 records in: "wasb://hdblobstorage@hdblobstorage.blob.core.windows.net//DonnotLaugel/DonnotLaugel/NetflixData_Train-20050531.csv"
# Successfully stored 31584587 records in: "wasb://hdblobstorage@hdblobstorage.blob.core.windows.net//DonnotLaugel/DonnotLaugel/NetflixData_Test-20050531.csv"
#
# Counters:
# Total records written : 100480507
# Total bytes written : 0
# Spillable Memory Manager spill count : 0
# Total bags proactively spilled: 0
# Total records proactively spilled: 0
#
# Job DAG:
# job_1422019453959_0954
#
#
# 2015-02-03 17:48:52,315 [main] WARN  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - No FileSystem for scheme: wasb. Not creating success file
# 2015-02-03 17:48:52,315 [main] WARN  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - No FileSystem for scheme: wasb. Not creating success file
# 2015-02-03 17:48:52,315 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at headnodehost/100.74.20.101:9010
# 2015-02-03 17:48:52,424 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2015-02-03 17:48:53,486 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Success!
#
# </pre><br />

# %%
content = %blob_ls /$PSEUDO/DonnotLaugel/
content
# Out:
#                                                  name  \
# 0      DonnotLaugel/DonnotLaugel/HistoNetflixData.csv
# 1   DonnotLaugel/DonnotLaugel/HistoNetflixData.csv...
# 2   DonnotLaugel/DonnotLaugel/HistoNetflixData.csv...
# 3   DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 4   DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 5   DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 6   DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 7   DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 8   DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 9   DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 10  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 11  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 12  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 13  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 14  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 15  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 16  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 17  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 18  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 19  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 20  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 21  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 22  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 23  DonnotLaugel/DonnotLaugel/NetflixData_Test-200...
# 24  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 25  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 26  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 27  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 28  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 29  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 30  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 31  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 32  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 33  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 34  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 35  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 36  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 37  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 38  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 39  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 40  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 41  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 42  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 43  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 44  DonnotLaugel/DonnotLaugel/NetflixData_Train-20...
# 45       DonnotLaugel/DonnotLaugel/allNetflixData.csv
# 46  DonnotLaugel/DonnotLaugel/allNetflixDataClean.csv
# 47  DonnotLaugel/DonnotLaugel/allNetflixDataClean....
# 48  DonnotLaugel/DonnotLaugel/allNetflixDataClean....
# 49  DonnotLaugel/DonnotLaugel/allNetflixDataClean....
# 50  DonnotLaugel/DonnotLaugel/allNetflixDataClean....
# 51  DonnotLaugel/DonnotLaugel/allNetflixDataClean....
# 52  DonnotLaugel/DonnotLaugel/allNetflixDataClean....
#
#                     last_modified              content_type  content_length  \
# 0   Tue, 03 Feb 2015 16:33:29 GMT                                         0
# 1   Tue, 03 Feb 2015 16:33:29 GMT  application/octet-stream               0
# 2   Tue, 03 Feb 2015 16:33:29 GMT  application/octet-stream           36568
# 3   Tue, 03 Feb 2015 17:02:14 GMT                                         0
# 4   Tue, 03 Feb 2015 17:02:14 GMT  application/octet-stream               0
# 5   Tue, 03 Feb 2015 17:02:12 GMT  application/octet-stream       498556627
# 6   Tue, 03 Feb 2015 17:02:12 GMT  application/octet-stream       500924019
# 7   Tue, 03 Feb 2015 17:02:13 GMT  application/octet-stream       498933507
# 8   Tue, 03 Feb 2015 17:02:14 GMT  application/octet-stream       500889693
# 9   Tue, 03 Feb 2015 17:02:14 GMT  application/octet-stream       428328195
# 10  Tue, 03 Feb 2015 17:48:49 GMT                                         0
# 11  Tue, 03 Feb 2015 17:48:49 GMT  application/octet-stream               0
# 12  Tue, 03 Feb 2015 17:48:48 GMT  application/octet-stream       168789448
# 13  Tue, 03 Feb 2015 17:48:48 GMT  application/octet-stream       170693918
# 14  Tue, 03 Feb 2015 17:48:48 GMT  application/octet-stream       172664284
# 15  Tue, 03 Feb 2015 17:48:48 GMT  application/octet-stream       167903975
# 16  Tue, 03 Feb 2015 17:48:48 GMT  application/octet-stream       140986393
# 17  Tue, 03 Feb 2015 16:09:09 GMT                                         0
# 18  Tue, 03 Feb 2015 16:09:09 GMT  application/octet-stream               0
# 19  Tue, 03 Feb 2015 16:09:08 GMT  application/octet-stream               0
# 20  Tue, 03 Feb 2015 16:09:08 GMT  application/octet-stream               0
# 21  Tue, 03 Feb 2015 16:09:08 GMT  application/octet-stream               0
# 22  Tue, 03 Feb 2015 16:09:09 GMT  application/octet-stream               0
# 23  Tue, 03 Feb 2015 16:09:09 GMT  application/octet-stream               0
# 24  Tue, 03 Feb 2015 17:02:12 GMT                                         0
# 25  Tue, 03 Feb 2015 17:02:12 GMT  application/octet-stream               0
# 26  Tue, 03 Feb 2015 17:02:11 GMT  application/octet-stream        38314308
# 27  Tue, 03 Feb 2015 17:02:11 GMT  application/octet-stream        35946888
# 28  Tue, 03 Feb 2015 17:02:11 GMT  application/octet-stream        37937400
# 29  Tue, 03 Feb 2015 17:02:11 GMT  application/octet-stream        35981222
# 30  Tue, 03 Feb 2015 17:02:11 GMT  application/octet-stream        34728806
# 31  Tue, 03 Feb 2015 17:48:47 GMT                                         0
# 32  Tue, 03 Feb 2015 17:48:47 GMT  application/octet-stream               0
# 33  Tue, 03 Feb 2015 17:48:46 GMT  application/octet-stream       368081487
# 34  Tue, 03 Feb 2015 17:48:46 GMT  application/octet-stream       366176989
# 35  Tue, 03 Feb 2015 17:48:46 GMT  application/octet-stream       364206623
# 36  Tue, 03 Feb 2015 17:48:47 GMT  application/octet-stream       368966940
# 37  Tue, 03 Feb 2015 17:48:47 GMT  application/octet-stream       322070608
# 38  Tue, 03 Feb 2015 16:09:08 GMT                                         0
# 39  Tue, 03 Feb 2015 16:09:08 GMT  application/octet-stream               0
# 40  Tue, 03 Feb 2015 16:09:07 GMT  application/octet-stream       536870935
# 41  Tue, 03 Feb 2015 16:09:07 GMT  application/octet-stream       536870907
# 42  Tue, 03 Feb 2015 16:09:07 GMT  application/octet-stream       536870907
# 43  Tue, 03 Feb 2015 16:09:07 GMT  application/octet-stream       536870915
# 44  Tue, 03 Feb 2015 16:09:07 GMT  application/octet-stream       463057001
# 45  Mon, 02 Feb 2015 16:59:38 GMT  application/octet-stream      2610540665
# 46  Tue, 03 Feb 2015 13:58:40 GMT                                         0
# 47  Tue, 03 Feb 2015 13:58:40 GMT  application/octet-stream               0
# 48  Tue, 03 Feb 2015 13:58:38 GMT  application/octet-stream       516205875
# 49  Tue, 03 Feb 2015 13:58:39 GMT  application/octet-stream       517147950
# 50  Tue, 03 Feb 2015 13:58:39 GMT  application/octet-stream       517401875
# 51  Tue, 03 Feb 2015 13:58:39 GMT  application/octet-stream       516689025
# 52  Tue, 03 Feb 2015 13:58:39 GMT  application/octet-stream       444567950
#
#     blob_type
# 0   BlockBlob
# 1   BlockBlob
# 2   BlockBlob
# 3   BlockBlob
# 4   BlockBlob
# 5   BlockBlob
# 6   BlockBlob
# 7   BlockBlob
# 8   BlockBlob
# 9   BlockBlob
# 10  BlockBlob
# 11  BlockBlob
# 12  BlockBlob
# 13  BlockBlob
# 14  BlockBlob
# 15  BlockBlob
# 16  BlockBlob
# 17  BlockBlob
# 18  BlockBlob
# 19  BlockBlob
# 20  BlockBlob
# 21  BlockBlob
# 22  BlockBlob
# 23  BlockBlob
# 24  BlockBlob
# 25  BlockBlob
# 26  BlockBlob
# 27  BlockBlob
# 28  BlockBlob
# 29  BlockBlob
# 30  BlockBlob
# 31  BlockBlob
# 32  BlockBlob
# 33  BlockBlob
# 34  BlockBlob
# 35  BlockBlob
# 36  BlockBlob
# 37  BlockBlob
# 38  BlockBlob
# 39  BlockBlob
# 40  BlockBlob
# 41  BlockBlob
# 42  BlockBlob
# 43  BlockBlob
# 44  BlockBlob
# 45  BlockBlob
# 46  BlockBlob
# 47  BlockBlob
# 48  BlockBlob
# 49  BlockBlob
# 50  BlockBlob
# 51  BlockBlob
# 52  BlockBlob

# %% [markdown]
# ##### On prépare une base pour tester nos scriptes (petites extract de la base de Train donc)

# %% [markdown]
# On ferme la connexion

# %%
# %blob_close
# Out:
# True
